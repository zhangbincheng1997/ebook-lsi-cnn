# %% [markdown]
# ### 加载数据

# %%
import tensorflow as tf
from keras import backend as K

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1, 2, 3" # GPU 列表

G = 4 # GPU 数量
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.5)
session = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options, allow_soft_placement=True))
K.set_session(session)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import numpy as np
train_q = np.load('data/train_q.npy')
train_a = np.load('data/train_a.npy')
train_y = np.load('data/train_y.npy')
test_q = np.load('data/test_q.npy')
test_a = np.load('data/test_a.npy')
test_y = np.load('data/test_y.npy')
test_id = np.load('data/test_id.npy')

# %% [markdown]
# ### 网络结构

# %%
# %load_ext autoreload
# %autoreload 2
from models import *

model = CNN2()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 200)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 200, 100)     55470100    input_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 200, 100)     55470100    input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 200, 256)     77056       embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 200, 256)     102656      embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 200, 256)     128256      embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 200, 256)     77056       embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 200, 256)     102656      embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 200, 256)     128256      embedding_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 256)     1024        conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 200, 256)     1024        conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 200, 256)     1024        conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 200, 256)     1024        conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 200, 256)     1024        conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 200, 256)     1024        conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 200, 256)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 200, 256)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 200, 256)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 200, 256)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 200, 256)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 200, 256)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 200, 128)     98432       activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 200, 128)     131200      activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 200, 128)     163968      activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 200, 128)     98432       activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 200, 128)     131200      activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 200, 128)     163968      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 200, 128)     512         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 200, 128)     512         conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 200, 128)     512         conv1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 200, 128)     512         conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 200, 128)     512         conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 200, 128)     512         conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 200, 128)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 200, 128)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 200, 128)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 200, 128)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 200, 128)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 200, 128)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 100, 128)     0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 100, 128)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 100, 128)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 100, 128)     0           activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 100, 128)     0           activation_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 100, 128)     0           activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 100, 384)     0           max_pooling1d_1[0][0]
#                                                                  max_pooling1d_2[0][0]
#                                                                  max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 100, 384)     0           max_pooling1d_4[0][0]
#                                                                  max_pooling1d_5[0][0]
#                                                                  max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 38400)        0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 38400)        0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 38400)        0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 38400)        0           flatten_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 76800)        0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          39322112    concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 512)          2048        dense_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 512)          0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           activation_13[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            513         dropout_3[0][0]
# ==================================================================================================
# Total params: 151,677,225
# Trainable params: 40,731,393
# Non-trainable params: 110,945,832
# __________________________________________________________________________________________________

# %%
# 模型可视化 https://keras-cn.readthedocs.io/en/latest/other/visualization/
from keras.utils import plot_model
from IPython import display

# pip install pydot=1.2.3
# pip install pydot-ng
# sudo apt-get install graphviz
plot_model(model, to_file="img/CNN2.png", show_shapes=True)
display.Image('img/CNN2.png')

# %% [markdown]
# ### 训练

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.utils import multi_gpu_model

EPOCHS = 10
BATCH_SIZE = 64 * G
VALIDATION_SPLIT = 0.3 # 30% 验证集

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model_path = 'model/CNN2.h5'
model_checkpoint = ModelCheckpoint(model_path, save_best_only=True, save_weights_only=True)
tensorboard = TensorBoard('log/CNN2', write_graph=True, write_images=True)

model = multi_gpu_model(model)

model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

model.fit([train_q, train_a], train_y, epochs=EPOCHS, batch_size=BATCH_SIZE, 
          validation_split=VALIDATION_SPLIT, shuffle=True, 
          callbacks=[early_stopping, model_checkpoint, tensorboard])
# Out:
# Train on 333913 samples, validate on 143106 samples
# Epoch 1/10
# 333913/333913 [==============================] - 455s 1ms/step - loss: 0.5280 - acc: 0.7410 - val_loss: 0.4869 - val_acc: 0.7574
# Epoch 2/10
# 333913/333913 [==============================] - 445s 1ms/step - loss: 0.4718 - acc: 0.7668 - val_loss: 0.4779 - val_acc: 0.7619
# Epoch 3/10
# 333913/333913 [==============================] - 444s 1ms/step - loss: 0.4459 - acc: 0.7821 - val_loss: 0.4656 - val_acc: 0.7688
# Epoch 4/10
# 333913/333913 [==============================] - 444s 1ms/step - loss: 0.4207 - acc: 0.7968 - val_loss: 0.4703 - val_acc: 0.7715
# Epoch 5/10
# 333913/333913 [==============================] - 444s 1ms/step - loss: 0.3955 - acc: 0.8114 - val_loss: 0.4931 - val_acc: 0.7721
# Epoch 6/10
# 333913/333913 [==============================] - 442s 1ms/step - loss: 0.3676 - acc: 0.8281 - val_loss: 0.4879 - val_acc: 0.7721
# Epoch 7/10
# 333913/333913 [==============================] - 444s 1ms/step - loss: 0.3392 - acc: 0.8432 - val_loss: 0.4762 - val_acc: 0.7739
# Epoch 8/10
# 333913/333913 [==============================] - 443s 1ms/step - loss: 0.3108 - acc: 0.8587 - val_loss: 0.4899 - val_acc: 0.7529
# Epoch 9/10
# 333913/333913 [==============================] - 443s 1ms/step - loss: 0.2844 - acc: 0.8733 - val_loss: 0.4905 - val_acc: 0.7694
# Epoch 10/10
# 333913/333913 [==============================] - 442s 1ms/step - loss: 0.2622 - acc: 0.8838 - val_loss: 0.5299 - val_acc: 0.7470

# %% [markdown]
# ### 预测

# %%
y_true = []
with open('data/submit_sample.txt', 'r') as f:
    for line in f.readlines():
        pro = line.strip().split(',')
        y_true.append(int(pro[1]))

# %%
# load the best model
model_path = 'model/CNN2.h5'
model.load_weights(model_path)
predicts = model.predict([test_q, test_a], batch_size=64, verbose=1)

with open('predict/CNN2.txt', 'w') as f:
    for i in range(len(test_id)):
        f.write('%d,%s\n' % (test_id[i], predicts[i][0]))

num = 0
for i in range(len(y_true)):
    if y_true[i] == 0 and predicts[i][0] < 0.5: num += 1
    if y_true[i] == 1 and predicts[i][0] >= 0.5: num += 1
print('%d / %d = %f' % (num, len(y_true), num / len(y_true)))
# Out:
# 1586/1586 [==============================] - 6s 4ms/step
# 1225 / 1586 = 0.772383
